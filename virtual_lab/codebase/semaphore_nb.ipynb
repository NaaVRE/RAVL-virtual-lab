h5", "/tmp/data/knmi/NL/HRW/2022/10/20/RAD_NL62_VOL_NA_202210200530.h5", "/tmp/data/knmi/NL/HRW/2022/10/20/RAD_NL62_VOL_NA_202210200545.h5", "/tmp/data/knmi/NL/HRW/2022/10/20/RAD_NL62_VOL_NA_202210200600.h5", "/tmp/data/knmi/NL/HRW/2022/10/20/RAD_NL62_VOL_NA_202210200615.h5", "/tmp/data/knmi/NL/HRW/2022/10/20/RAD_NL62_VOL_NA_202210200630.h5", "/tmp/data/knmi/NL/HRW/2022/10/20/RAD_NL62_VOL_NA_202210200645.h5", "/tmp/data/knmi/NL/HRW/2022/10/20/RAD_NL62_VOL_NA_202210200700.h5", "/tmp/data/knmi/NL/HRW/2022/10/20/RAD_NL62_VOL_NA_202210200715.h5", "/tmp/data/knmi/NL/HRW/2022/10/20/RAD_NL62_VOL_NA_202210200730.h5", "/tmp/data/knmi/NL/HRW/2022/10/20/RAD_NL62_VOL_NA_202210200745.h5", "/tmp/data/knmi/NL/HRW/2022/10/20/RAD_NL62_VOL_NA_202210200800.h5", "/tmp/data/knmi/NL/HRW/2022/10/20/RAD_NL62_VOL_NA_202210200815.h5", "/tmp/data/knmi/NL/HRW/2022/10/20/RAD_NL62_VOL_NA_202210200830.h5", "/tmp/data/knmi/NL/HRW/2022/10/20/RAD_NL62_VOL_NA_202210200845.h5", "/tmp/data/knmi/NL/HRW/2022/10/20/RAD_NL62_VOL_NA_202210200900.h5", "/tmp/data/knmi/NL/HRW/2022/10/20/RAD_NL62_VOL_NA_202210200915.h5", "/tmp/data/knmi/NL/HRW/2022/10/20/RAD_NL62_VOL_NA_202210200930.h5", "/tmp/data/knmi/NL/HRW/2022/10/20/RAD_NL62_VOL_NA_202210200945.h5", "/tmp/data/knmi/NL/HRW/2022/10/20/RAD_NL62_VOL_NA_202210201000.h5", "/tmp/data/knmi/NL/HRW/2022/10/20/RAD_NL62_VOL_NA_202210201015.h5", "/tmp/data/knmi/NL/HRW/2022/10/20/RAD_NL62_VOL_NA_202210201030.h5", "/tmp/data/knmi/NL/HRW/2022/10/20/RAD_NL62_VOL_NA_202210201045.h5", "/tmp/data/knmi/NL/HRW/2022/10/20/RAD_NL62_VOL_NA_202210201100.h5", "/tmp/data/knmi/NL/HRW/2022/10/20/RAD_NL62_VOL_NA_202210201115.h5", "/tmp/data/knmi/NL/HRW/2022/10/20/RAD_NL62_VOL_NA_202210201130.h5", "/tmp/data/knmi/NL/HRW/2022/10/20/RAD_NL62_VOL_NA_202210201145.h5"]
param_semaphore = 16

# %%
# New splitter with semaphore 
def rewrite_list_nested(in_list,semaphore):
    """
    B. Wijers 
    23-02-2024
    b.c.wijers@uva.nl
    for Lifewatch - NaaVRE
    
    Splitter
    input:
        list with elements
        TYPE: list
    output:
        list with semaphore number of nested elements
        TYPE: List[list]
    Notes:
    Will attempt to make an even split.
    In case no even splits can be made, the last
    set of elements which could not be split
    are evenly distributed across the nested lists.
    Even distribution means that each nested list
    receives up to a maximum of one extra element.
    In these cases the nested lists have varying
    amount of elements but will never exceed the
    difference by more than 1 element. 
    """
    out_list = []
    # Get the length of the list
    in_list_len = len(in_list)
    # Expecting integers so we can use floor division
    # Determine the maximum even-splits we can do
    worker_chunk_size = in_list_len // semaphore 
    # Determine how many elements could not be split
    leftovers = in_list_len%semaphore
    while in_list:
        # Set leftover to 0
        leftover = 0
        # If we could not make even-split
        if leftovers:
            # Can not exceed one element addition per split
            leftover = 1
            # Update the number of leftovers
            leftovers -= leftover
        # Add the nested list. If there was a leftover, add it
        out_list.append(in_list[:worker_chunk_size+leftover])
        # Update the input list and remove the elements we added to 
        # output list
        in_list = in_list[worker_chunk_size+leftover:]
    return out_list

out_list = rewrite_list_nested(in_list = input_list,
							   semaphore=param_semaphore)

# %%
# Print some info about the output
print(f"Total number of nested lists: {len(out_list)}")
for idx,nested_list in enumerate(out_list):
    print(f"nested_list {idx+1}")
    print(f"Number of list elements = {len(nested_list)}")
    print(f"List elements:")
    for n_element, element in enumerate(nested_list):
        print(f"{n_element+1}: \t {element}")
    print("-----------------------------------------------------")
# Out:
# Total number of nested lists: 16
# nested_list 1
# Number of list elements = 18
# List elements:
# 1: 	 /tmp/data/knmi/NL/HRW/2022/10/17/RAD_NL62_VOL_NA_202210171200.h5
# 2: 	 /tmp/data/knmi/NL/HRW/2022/10/17/RAD_NL62_VOL_NA_202210171215.h5
# 3: 	 /tmp/data/knmi/NL/HRW/2022/10/17/RAD_NL62_VOL_NA_202210171230.h5
# 4: 	 /tmp/data/knmi/NL/HRW/2022/10/17/RAD_NL62_VOL_NA_202210171245.h5
# 5: 	 /tmp/data/knmi/NL/HRW/2022/10/17/RAD_NL62_VOL_NA_202210171300.h5
# 6: 	 /tmp/data/knmi/NL/HRW/2022/10/17/RAD_NL62_VOL_NA_202210171315.h5
# 7: 	 /tmp/data/knmi/NL/HRW/2022/10/17/RAD_NL62_VOL_NA_202210171330.h5
# 8: 	 /tmp/data/knmi/NL/HRW/2022/10/17/RAD_NL62_VOL_NA_202210171345.h5
# 9: 	 /tmp/data/knmi/NL/HRW/2022/10/17/RAD_NL62_VOL_NA_202210171400.h5
# 10: 	 /tmp/data/knmi/NL/HRW/2022/10/17/RAD_NL62_VOL_NA_202210171415.h5
# 11: 	 /tmp/data/knmi/NL/HRW/2022/10/17/RAD_NL62_VOL_NA_202210171430.h5
# 12: 	 /tmp/data/knmi/NL/HRW/2022/10/17/RAD_NL62_VOL_NA_202210171445.h5
# ...
